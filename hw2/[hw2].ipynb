# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("data/movie_metadata_cleaned.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'movie_title', 'color', 'director_name',
#        'num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes',
#        'gross', 'genres', 'actor_1_name', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Get the top 10 directors with most movies directed and use a boxplot for their gross earnings

# %%
#Recopy dataset from original to new dataset to avoid altering of information
data1 = data.copy()
#Add new column "count" where its values are the number of occurrences of the director names per movie title
data1["count"] = data1.groupby("director_name")["movie_title"].transform(pd.Series.count)
#Sort the values by the highest count of occurrence
data1.sort_values("count", inplace=True, ascending=False)

#Remove the Duplicates of all the Director names with "0" as name
topdir = data1.drop_duplicates(subset="director_name", keep="first", inplace=False, ignore_index=False)
#print the Top 10 Directors with most movies
print(topdir[["director_name","count"]][1:11])
#create the Figure for the boxplot
fig = plt.figure(figsize =(10, 7))
#assign values for the boxplot
forboxplot = topdir[["gross","director_name"]][1:11]
#create boxplot
forboxplot.boxplot()
#create the Labels
plt.xlabel("Top 10 Directors")
plt.ylabel("Gross Earnings")
# Out:
#           director_name  count
# 284    Steven Spielberg     26
# 2291        Woody Allen     22
# 973      Clint Eastwood     20
# 3100    Martin Scorsese     20
# 1777       Ridley Scott     17
# 4483          Spike Lee     16
# 1400         Tim Burton     16
# 4484  Steven Soderbergh     16
# 2281       Renny Harlin     15
# 607        Oliver Stone     14
# Text(0, 0.5, 'Gross Earnings')

# %% [markdown]
# ## Plot the following variables in one graph:
#
# - num_critic_for_reviews
# - IMDB score
# - gross

# %%
#Simply plot the for the 3 variaables given
sns.relplot(x = "num_critic_for_reviews", y ="imdb_score", hue = "gross", data=data)
plt.show()

# %% [markdown]
# ## Compute Sales (Gross - Budget), add it as another column

# %%
#Recopy dataset from original to new dataset to avoid altering of information
data2 = data
#sort values of new dataset
data2 = data.sort_values("Unnamed: 0", inplace=False, ascending=True)
# Compute the Sales
data2["sales"] = data2["gross"] - data2["budget"]
data2["sales"]
# Out:
# 0       523505847.0
# 1         9404152.0
# 2       -44925825.0
# 3       198130642.0
# 4               0.0
#            ...
# 5039            0.0
# 5040        -1400.0
# 5041        10443.0
# 5042        84122.0
# 5043            0.0
# Name: sales, Length: 5044, dtype: float64

# %% [markdown]
# ## Which directors garnered the most total sales?

# %%
#sort values by top sales
topsalesdirector = data2.sort_values("sales", inplace=False, ascending=False)
#remove duplicates of Director Names
topsalesdirector.drop_duplicates(subset="director_name", keep="first", inplace=True, ignore_index=False)
#print output
topsalesdirector[["director_name","sales"]][1:11]
# Out:
#           director_name        sales
# 29      Colin Trevorrow  502177271.0
# 3024       George Lucas  449935665.0
# 3080   Steven Spielberg  424449459.0
# 17          Joss Whedon  403279547.0
# 509        Roger Allers  377783777.0
# 66    Christopher Nolan  348316061.0
# 439           Gary Ross  329999255.0
# 812          Tim Miller  305024263.0
# 186    Francis Lawrence  294645577.0
# 521       Pierre Coffin  292049635.0

# %% [markdown]
# ## Plot sales and average likes as a scatterplot. Fit it with a line.

# %%
data3 = data2
#create figure for plot
plt.figure(figsize=(10,8))
#create plot
sns.regplot(x="sales",y = "movie_facebook_likes", data=data3)
#creat title
plt.title("Scatter Plot of Sales and Average like", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Sales and Average like')

# %% [markdown]
# ## Which of these genres are the most profitable? Plot their sales using different histograms, superimposed in the same axis.
#
# - Romance
# - Comedy
# - Action
# - Fantasy

# %%
data4 = data3
ax = sns.histplot(data4[data4['genres'] == "Romance"]["sales"], color="red", label="Romance", kde=True, stat="density", linewidth=0)
sns.histplot(data4[data4['genres'] == "Comedy"]["sales"], color="teal", label="Comdey", kde=True, stat="density", linewidth=0, ax=ax)
sns.histplot(data4[data4['genres'] == "Action"]["sales"], color="blue", label="Action", kde=True, stat="density", linewidth=0, ax=ax)
sns.histplot(data4[data4['genres'] == "Fantasy"]["sales"], color="yellow", label="Fantasy", kde=True, stat="density", linewidth=0, ax=ax)
ax.legend()

# %% [markdown]
# ## For each of movie, compute average likes of the three actors and store it as a new variable
#
# Read up on the mean function.
#
# Store it as a new column, average_actor_likes.

# %% [markdown]
# ## Copying the whole dataframe

# %%
df = data.copy()
df.head()
# Out:
#       Unnamed: 0                   movie_title             color  \
# 4517        4517     b'Wolf Creek            '             Color
# 3604        3604    b'War & Peace            '             Color
# 1175        1175  b"McHale's Navy            "   Black and White
# 4327        4327          b'Wings            '             Color
# 2828        2828     b'The Border            '             Color
#
#      director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 4517             0                     2.0       0.0                      0.0
# 3604             0                    10.0       0.0                      0.0
# 1175             0                     4.0      30.0                      0.0
# 4327             0                    19.0      30.0                      0.0
# 2828             0                     1.0      41.0                      0.0
#
#       actor_3_facebook_likes        actor_2_name  actor_1_facebook_likes  ...  \
# 4517                   206.0        John Jarratt                   511.0  ...
# 3604                   502.0  Tuppence Middleton                  1000.0  ...
# 1175                   253.0       Gavin MacLeod                   870.0  ...
# 4327                   424.0            Tim Daly                   685.0  ...
# 2828                     2.0    Marian Dziedziel                    70.0  ...
#
#       language    country content_rating  budget  title_year  \
# 4517   English  Australia              0     0.0         0.0
# 3604   English         UK          TV-14     0.0         0.0
# 1175   English        USA           TV-G     0.0         0.0
# 4327   English        USA              0     0.0         0.0
# 2828    Polish     Poland              0     0.0         0.0
#
#      actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 4517                  457.0         7.1         2.00                954.0
# 3604                  888.0         8.2        16.00              11000.0
# 1175                  284.0         7.5         4.00                455.0
# 4327                  511.0         7.3         1.33               1000.0
# 2828                    2.0         7.4         0.00                 64.0
#
#       count
# 4517    104
# 3604    104
# 1175    104
# 4327    104
# 2828    104
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Min-Max Normalization
#
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to a common scale, without distorting differences in the ranges of values. For machine learning, every dataset does not require normalization. It is required only when features have different ranges.
#
# The min-max approach (often called normalization) rescales the feature to a hard and fast range of [0,1] by subtracting the minimum value of the feature then dividing by the range. We can apply the min-max scaling in Pandas using the .min() and .max() methods.
#
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$

# %% [markdown]
# ### Normalize each numeric column (those that have types integer or float) of the copied dataframe (df)

# %%
from pandas.api.types import is_numeric_dtype

#for loop to check each column if has numeric values
for column in df:
    if is_numeric_dtype(df[column]):
        max = df[column].max()
        min = df[column].min()
        df[column] = (df[column] - min) / (max-min)
df
# Out:
#       Unnamed: 0                   movie_title             color  \
# 4517    0.895697     b'Wolf Creek            '             Color
# 3604    0.714654    b'War & Peace            '             Color
# 1175    0.232996  b"McHale's Navy            "   Black and White
# 4327    0.858021          b'Wings            '             Color
# 2828    0.560777     b'The Border            '             Color
# ...          ...                           ...               ...
# 3321    0.658537      b'The Girl on the Train'             Color
# 3319    0.658140               b'Undiscovered'             Color
# 3318    0.657942           b'Flame and Citron'             Color
# 3315    0.657347          b'Princess Kaiulani'             Color
# 5043    1.000000        b'Starting Over Again'                 0
#
#              director_name  num_critic_for_reviews  duration  \
# 4517                     0                0.002460  0.000000
# 3604                     0                0.012300  0.000000
# 1175                     0                0.004920  0.158730
# 4327                     0                0.023370  0.158730
# 2828                     0                0.001230  0.216931
# ...                    ...                     ...       ...
# 3321         André Téchiné                0.081181  0.555556
# 3319           Meiert Avis                0.050431  0.513228
# 3318  Ole Christian Madsen                0.098401  0.238095
# 3315            Marc Forby                0.031980  0.513228
# 5043        Olivia Lamasan                0.000000  0.000000
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4517                 0.000000                0.008957        John Jarratt
# 3604                 0.000000                0.021826  Tuppence Middleton
# 1175                 0.000000                0.011000       Gavin MacLeod
# 4327                 0.000000                0.018435            Tim Daly
# 2828                 0.000000                0.000087    Marian Dziedziel
# ...                       ...                     ...                 ...
# 3321                 0.001087                0.004261      Ronit Elkabetz
# 3319                 0.000000                0.010000          Kip Pardue
# 3318                 0.001217                0.004522     Thure Lindhardt
# 3315                 0.000130                0.008870         Will Patton
# 5043                 0.000000                0.000000        Toni Gonzaga
#
#       actor_1_facebook_likes  ...  language      country content_rating  \
# 4517                0.000798  ...   English    Australia              0
# 3604                0.001563  ...   English           UK          TV-14
# 1175                0.001359  ...   English          USA           TV-G
# 4327                0.001070  ...   English          USA              0
# 2828                0.000109  ...    Polish       Poland              0
# ...                      ...  ...       ...          ...            ...
# 3321                0.001505  ...    French       France        Unrated
# 3319                0.001441  ...   English      Germany          PG-13
# 3318                0.000895  ...    Danish      Denmark      Not Rated
# 3315                0.001061  ...   English          USA             PG
# 5043                0.000000  ...         0  Philippines             PG
#
#         budget  title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 4517  0.000000    0.000000               0.003336    0.747368     0.125000
# 3604  0.000000    0.000000               0.006482    0.863158     1.000000
# 1175  0.000000    0.000000               0.002073    0.789474     0.250000
# 4327  0.000000    0.000000               0.003730    0.768421     0.083125
# 2828  0.000000    0.000000               0.000015    0.778947     0.000000
# ...        ...         ...                    ...         ...          ...
# 3321  0.000000    0.996528               0.001226    0.631579     0.146875
# 3319  0.000737    0.994544               0.002730    0.442105     0.146875
# 3318  0.003684    0.996032               0.001438    0.768421     0.146875
# 3315  0.000737    0.996528               0.003920    0.652632     0.146875
# 5043  0.000000    0.999008               0.000000    0.000000     0.000000
#
#      movie_facebook_likes  count
# 4517             0.002734    1.0
# 3604             0.031519    1.0
# 1175             0.001304    1.0
# 4327             0.002865    1.0
# 2828             0.000183    1.0
# ...                   ...    ...
# 3321             0.000344    0.0
# 3319             0.000367    0.0
# 3318             0.000000    0.0
# 3315             0.000000    0.0
# 5043             0.000000    0.0
#
# [5044 rows x 30 columns]
